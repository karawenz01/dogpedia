# %% [markdown]
# # pymongo (Database connection)

# %%
import pymongo

# %%
from config import dbuser, dbpassword

# %%
# database connection setup
conn = f"mongodb://{dbuser}:{dbpassword}@ds018558.mlab.com:18558/dogpedia"
client = pymongo.MongoClient(conn)
db = client.dogpedia

# %%
collection = db.breed_trait

# %%
collection.find_one({'breed':'Alaskan Malamute'})
# Out:
# {'_id': ObjectId('5b8f4e6b50f960048cb6b1d9'), 'apt_friendly': 1, 'breed': 'Alaskan Malamute', 'energy': 5, 'shedding': 5}

# %%
collection = db.breeds

# %%
collection.find_one()['breed']
# Out:
# ['Affenpinscher',
#  'Afghan Hound',
#  'Airedale Terrier',
#  'Akita',
#  'Alaskan Malamute',
#  'American Bulldog',
#  'American Eskimo Dog',
#  'American Staffordshire Terrier',
#  'American Water Spaniel',
#  'Australian Kelpie',
#  'Australian Shepherd',
#  'Australian Terrier',
#  'Basenji',
#  'Basset Hound',
#  'Beagle',
#  'Bearded Collie',
#  'Bedlington Terrier',
#  'Bernese Mountain Dog',
#  'Bichon Frise',
#  'Black and Tan Coonhound',
#  'Black Mouth Cur',
#  'Black Russian Terrier',
#  'Bloodhound',
#  'Blue Lacy',
#  'Bluetick Coonhound',
#  'Boerboel',
#  'Bolognese',
#  'Border Collie',
#  'Border Terrier',
#  'Borzoi',
#  'Boston Terrier',
#  'Boxer',
#  'Boykin Spaniel',
#  'Briard',
#  'Brussels Griffon',
#  'Bull Terrier',
#  'Bullmastiff',
#  'Cairn Terrier',
#  'Canaan Dog',
#  'Catahoula Leopard Dog',
#  'Cavalier King Charles Spaniel',
#  'Chesapeake Bay Retriever',
#  'Chihuahua',
#  'Chinook',
#  'Chow Chow',
#  'Clumber Spaniel',
#  'Cockapoo',
# ...

# %%
collection_pet_stores = db.pet_stores

# %%
states = collection_pet_stores.find_one()

# %%
states
# Out:
# {'_id': ObjectId('5b900dbb9b4232213f5c1cbd'),
#  'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-9818386.2124, 4163287.837899998],
#       [-9529523.3771, 4161799.1404],
#       [-9482684.0315, 3876910.5490000024],
#       [-9450352.2873, 3798257.8574],
#       [-9477756.029, 3744785.0591999963],
#       [-9462420.322, 3632837.714400001],
#       [-9751468.059, 3632418.8907999992],
#       [-9730098.0563, 3590634.601599999],
#       [-9742495.2628, 3539648.3206999972],
#       [-9840088.949, 3551124.9184999987],
#       [-9848794.5785, 3749385.6281000003],
#       [-9807012.0321, 4149241.458800003],
#       [-9818386.2124, 4163287.837899998]]]},
#    'properties': {'GEO_ID': '0400000US01',
#     'STATE': '01',
#     'NAME': 'Alabama',
#     'LSAD': '',
#     'SHAPE_AREA': 190116188785,
#     'SHAPE_LEN': 2245729.04401,
#     'BUSINESS': 85}},
#   {'type': 'Feature',
# ...

# %%
type(states)
# Out:
# dict

# %%
collection_breeds_

# %% [markdown]
# # Flask_pymongo (DB connection in Flask environment)

# %%
from flask import Flask, jsonify, render_template
from flask_pymongo import PyMongo

# %%
app = Flask(__name__)

# Use pymongo to set up mongo connection and access a database
app.config["MONGO_URI"] = f"mongodb://{dbuser}:{dbpassword}@ds018558.mlab.com:18558/dogpedia"
mongo = PyMongo(app)

# %%
breeds = mongo.db.breeds.find_one()['breed']

# %%
type(breeds)
# Out:
# <class 'list'>

# %%
breed = "Borzoi"

# %%
breed_traits = mongo.db.breed_trait.find_one({'breed':breed})

# %%
breed_traits
# Out:
# {'_id': ObjectId('5b8f4e6b50f960048cb6b1f2'), 'apt_friendly': 5, 'breed': 'Borzoi', 'energy': 2, 'shedding': 5}

# %% [markdown]
# # Read Geojson file

# %%
import json
from pprint import pprint

# %%
data = json.loads(open('dataset/petStoreStatesData.json').read())

# %%
type(data)
# Out:
# <class 'dict'>

# %%
states = []
for state in data['features']:
    states.append(state['properties']['NAME'])

# %%
len(states)
# Out:
# 51

# %% [markdown]
# # Insert a number of business data into geojson and store the data in MongoDB

# %%
import pandas as pd

# %%
data_df = pd.read_csv('dataset/BP_2016_00A1_with_ann.csv')

# %%
data_df
# Out:
#    Geographic identifier code  Id2  Geographic area name  2012 NAICS code  \
# 0                 0400000US01    1               Alabama           453910
# 1                 0400000US02    2                Alaska           453910
# 2                 0400000US04    4               Arizona           453910
# 3                 0400000US05    5              Arkansas           453910
# 4                 0400000US06    6            California           453910
# 5                 0400000US08    8              Colorado           453910
# 6                 0400000US09    9           Connecticut           453910
# 7                 0400000US10   10              Delaware           453910
# 8                 0400000US11   11  District of Columbia           453910
# 9                 0400000US12   12               Florida           453910
# 10                0400000US13   13               Georgia           453910
# 11                0400000US15   15                Hawaii           453910
# ...

# %%
values = list(data_df['Number of establishments'])
len(values)
# Out:
# 51

# %%
i = 0
for state in data['features']:    
    state['properties']['BUSINESS'] = values[i]
    i += 1

# %%
pprint(data)
# Out:
# {'features': [{'geometry': {'coordinates': [[[-9818386.2124, 4163287.837899998],
#                                              [-9529523.3771, 4161799.1404],
#                                              [-9482684.0315,
#                                               3876910.5490000024],
#                                              [-9450352.2873, 3798257.8574],
#                                              [-9477756.029, 3744785.0591999963],
#                                              [-9462420.322, 3632837.714400001],
#                                              [-9751468.059, 3632418.8907999992],
#                                              [-9730098.0563, 3590634.601599999],
#                                              [-9742495.2628,
#                                               3539648.3206999972],
#                                              [-9840088.949, 3551124.9184999987],
#                                              [-9848794.5785,
# ...

# %%
type(data)
# Out:
# <class 'dict'>

# %%
my_dict = {"geo": data}

# %%
my_dict
# Out:
# {'geo': {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'geometry': {'type': 'Polygon', 'coordinates': [[[-9818386.2124, 4163287.837899998], [-9529523.3771, 4161799.1404], [-9482684.0315, 3876910.5490000024], [-9450352.2873, 3798257.8574], [-9477756.029, 3744785.0591999963], [-9462420.322, 3632837.714400001], [-9751468.059, 3632418.8907999992], [-9730098.0563, 3590634.601599999], [-9742495.2628, 3539648.3206999972], [-9840088.949, 3551124.9184999987], [-9848794.5785, 3749385.6281000003], [-9807012.0321, 4149241.458800003], [-9818386.2124, 4163287.837899998]]]}, 'properties': {'GEO_ID': '0400000US01', 'STATE': '01', 'NAME': 'Alabama', 'LSAD': '', 'SHAPE_AREA': 190116188785, 'SHAPE_LEN': 2245729.04401, 'BUSINESS': 85}}, {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[-18716026.9087, 9783256.280900002], [-18537607.5262, 9915776.726300001], [-18413045.7651, 9992876.123000003], [-18301004.8817, 10037731.816600002], [-18229030.931, 10029383.0484],
# ...

# %%
collection = db.pet_stores

# %%
collection.insert_one(my_dict)

# %%
pprint(collection.find_one()['geo'])
# Out:
# {'features': [{'geometry': {'coordinates': [[[-9818386.2124, 4163287.837899998],
#                                              [-9529523.3771, 4161799.1404],
#                                              [-9482684.0315,
#                                               3876910.5490000024],
#                                              [-9450352.2873, 3798257.8574],
#                                              [-9477756.029, 3744785.0591999963],
#                                              [-9462420.322, 3632837.714400001],
#                                              [-9751468.059, 3632418.8907999992],
#                                              [-9730098.0563, 3590634.601599999],
#                                              [-9742495.2628,
#                                               3539648.3206999972],
#                                              [-9840088.949, 3551124.9184999987],
#                                              [-9848794.5785,
# ...

# %%
states = collection.find_one()['geo']

# %%
pprint(states['features'])
# Out:
# [{'geometry': {'coordinates': [[[-9818386.2124, 4163287.837899998],
#                                 [-9529523.3771, 4161799.1404],
#                                 [-9482684.0315, 3876910.5490000024],
#                                 [-9450352.2873, 3798257.8574],
#                                 [-9477756.029, 3744785.0591999963],
#                                 [-9462420.322, 3632837.714400001],
#                                 [-9751468.059, 3632418.8907999992],
#                                 [-9730098.0563, 3590634.601599999],
#                                 [-9742495.2628, 3539648.3206999972],
#                                 [-9840088.949, 3551124.9184999987],
#                                 [-9848794.5785, 3749385.6281000003],
#                                 [-9807012.0321, 4149241.458800003],
#                                 [-9818386.2124, 4163287.837899998]]],
#                'type': 'Polygon'},
#   'properties': {'BUSINESS': 85,
# ...

# %%
for state in states['features']:
    print(state['geometry']['type'])
# Out:
# Polygon
# MultiPolygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# MultiPolygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# Polygon
# MultiPolygon
# Polygon
# Polygon
# Polygon
# Polygon

# %%
import requests

# %%
geojson(http://data.beta.nyc//dataset/d6ffa9a4-c598-4b18-8caf-14abde6a5755/resource/74cdcc33-512f-439c-a43e-c09588c4b391/download/60dbe69bcd3640d5bedde86d69ba7666geojsonmedianhouseholdincomecensustract.geojson)
# Out:
#   File "<ipython-input-42-d859674a4276>", line 1
#     geojson(http://data.beta.nyc//dataset/d6ffa9a4-c598-4b18-8caf-14abde6a5755/resource/74cdcc33-512f-439c-a43e-c09588c4b391/download/60dbe69bcd3640d5bedde86d69ba7666geojsonmedianhouseholdincomecensustract.geojson)
#                 ^
# SyntaxError: invalid syntax
